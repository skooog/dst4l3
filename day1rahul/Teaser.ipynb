# %% [markdown]
# #Teaser
#
# This is my first note.
#
# >This is my quote.
#
#     Verbatim monospace codey text
#
# * first item
# * second item
#
#
# 1. first item
# 2. first item
#
# http://zombo.com
#
# [ZOMBOCOM](http://zombo.com)
#
# Here is a rabbit skeleton: ![alt text](https://img0.etsystatic.com/000/0/5690714/il_570xN.160200932.jpg "delightful tooltip!")
#
# Here is another: ![rabbits plinkity plinkity plink](http://www.timetrips.co.uk/bonefull-rabbit.gif "eldritch rodentia")
#
# ```python
# def f():
#     return None
#
# ```
#
# Writing mathematics by enclosing it in dollar signs and escaping the character with a backslash. Let's say that $\alpha=3$
#
# Then we find that, with double dollar signs the equation goes in the middle of page $$\alpha + 1 = 4 .$$
# You can do all sorts of LaTeX math symbols. And you can do unicode chars directly. ¶

# %%
# !pip install seaborn
# Out:
# Downloading/unpacking seaborn
# ...
#   Running setup.py (path:/private/var/folders/jj/81xc3zyd7md_z40q1nc99fqw0000gn/T/pip_build_skoog/seaborn/setup.py) egg_info for package seaborn
# ...
#   Running setup.py install for seaborn
# ...
# Cleaning up...

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)

# %%
pd.__version__
# Out:
# '0.14.1'

# %% [markdown]
# Get Cheatsheet:
#
# from https://drive.google.com/folderview?id=0ByIrJAE4KMTtaGhRcXkxNHhmY2M&usp=sharing

# %%
df=pd.read_csv("all.csv", header=None,
               names=["rating", 'review_count', 'isbn', 'booktype','author_url', 'year', 'genre_urls', 'dir','rating_count', 'name'],
)
df.head()
# Out:
#    rating review_count        isbn         booktype  \
# 0    4.40       136455  0439023483  good_reads:book
# 1    4.41        16648  0439358078  good_reads:book
# 2    3.56        85746  0316015849  good_reads:book
# 3    4.23        47906  0061120081  good_reads:book
# 4    4.23        34772  0679783261  good_reads:book
#
#                                           author_url  year  \
# 0  https://www.goodreads.com/author/show/153394.S...  2008
# 1  https://www.goodreads.com/author/show/1077326....  2003
# 2  https://www.goodreads.com/author/show/941441.S...  2005
# 3  https://www.goodreads.com/author/show/1825.Har...  1960
# 4  https://www.goodreads.com/author/show/1265.Jan...  1813
#
#                                           genre_urls  \
# 0  /genres/young-adult|/genres/science-fiction|/g...
# 1  /genres/fantasy|/genres/young-adult|/genres/fi...
# 2  /genres/young-adult|/genres/fantasy|/genres/ro...
# 3  /genres/classics|/genres/fiction|/genres/histo...
# ...

# %% [markdown]
# ##Vectorization
#
# The python numerical stack is based on a concept called vectorization. You have seen this in spreadsheets where you manipulate an entire column.
#
# Whats the idea? It is that cpu's have some ability to carry out multiple things at one time, and we should use it to increase speed. But its also something else: there is a simplicity of notation. For example, see the following

# %%
a=[1,2,3,4,5]
b=[1,2,3,4,5]
print type(a)
print "============="
for index,aitem in enumerate(a):
    print a[index]*b[index]
# Out:
# <type 'list'>
# ...
# 1
# 4
# 9
# 16
# 25

# %%
a=np.array([1,2,3,4,5])
print type(a)
b=np.array([1,2,3,4,5])

print a*b
# Out:
# [ 1  4  9 16 25]

# %%
a+1
# Out:
# array([2, 3, 4, 5, 6])

# %% [markdown]
# ##Pandas

# %%
df=pd.read_csv("all.csv", header=None,
               names=["rating", 'review_count', 'isbn', 'booktype','author_url', 'year', 'genre_urls', 'dir','rating_count', 'name'],
)
df.head()
# Out:
#    rating review_count        isbn         booktype                                         author_url  year                                         genre_urls                                                dir rating_count                                               name
# 0    4.40       136455  0439023483  good_reads:book  https://www.goodreads.com/author/show/153394.S...  2008  /genres/young-adult|/genres/science-fiction|/g...                dir01/2767052-the-hunger-games.html      2958974            The Hunger Games (The Hunger Games, #1)
# 1    4.41        16648  0439358078  good_reads:book  https://www.goodreads.com/author/show/1077326....  2003  /genres/fantasy|/genres/young-adult|/genres/fi...  dir01/2.Harry_Potter_and_the_Order_of_the_Phoe...      1284478  Harry Potter and the Order of the Phoenix (Har...
# ...

# %% [markdown]
# Notice we have a table! A spreadsheet! And it indexed the rows. Lets see the types of the columns...
#
# ![](files/pandastruct.png)

# %%
df.dtypes
# Out:
# rating          float64
# review_count     object
# isbn             object
# booktype         object
# author_url       object
# year            float64
# genre_urls       object
# dir              object
# rating_count     object
# name             object
# dtype: object

# %%
df.shape
# Out:
# (6000, 10)

# %%
df.columns
# Out:
# Index([u'rating', u'review_count', u'isbn', u'booktype', u'author_url', u'year', u'genre_urls', u'dir', u'rating_count', u'name'], dtype='object')

# %%
type(df.rating), type(df)
# Out:
# (pandas.core.series.Series, pandas.core.frame.DataFrame)

# %%
100*np.mean(df.rating < 3.0)
# Out:
# 0.066666666666666666

# %%
df[df.rating > 4.5]
# Out:
#       rating review_count        isbn         booktype                                         author_url  year                                         genre_urls                                                dir rating_count                                               name
# 17      4.58         1314  0345538374  good_reads:book  https://www.goodreads.com/author/show/656983.J...  1973  /genres/fantasy|/genres/classics|/genres/scien...       dir01/30.J_R_R_Tolkien_4_Book_Boxed_Set.html        68495                    J.R.R. Tolkien 4-Book Boxed Set
# 162     4.55        15777  075640407X  good_reads:book  https://www.goodreads.com/author/show/108424.P...  2007                    /genres/fantasy|/genres/fiction             dir02/186074.The_Name_of_the_Wind.html       210018  The Name of the Wind (The Kingkiller Chronicle...
# ...

# %%
ratingseries=df.rating[df.rating.notnull()]
ratingseries
# Out:
# 0     4.40
# 1     4.41
# 2     3.56
# 3     4.23
# 4     4.23
# 5     4.25
# 6     4.22
# 7     4.38
# 8     3.79
# 9     4.18
# 10    4.03
# 11    3.72
# 12    4.36
# 13    4.05
# 14    3.72
# ...
# 5985    3.61
# 5986    4.06
# 5987    4.26
# 5988    4.34
# 5989    3.36
# 5990    4.12
# 5991    4.20
# 5992    3.89
# 5993    4.09
# 5994    4.37
# 5995    4.17
# 5996    3.99
# 5997    3.78
# 5998    3.91
# 5999    4.35
# Name: rating, Length: 5998, dtype: float64

# %%
df[['rating','name']]
# Out:
#       rating                                               name
# 0       4.40            The Hunger Games (The Hunger Games, #1)
# 1       4.41  Harry Potter and the Order of the Phoenix (Har...
# 2       3.56                            Twilight (Twilight, #1)
# 3       4.23                              To Kill a Mockingbird
# 4       4.23                                Pride and Prejudice
# 5       4.25                                 Gone with the Wind
# 6       4.22  The Chronicles of Narnia (Chronicles of Narnia...
# 7       4.38                                    The Giving Tree
# 8       3.79                                        Animal Farm
# 9       4.18  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 10      4.03                                Memoirs of a Geisha
# 11      3.72             The Da Vinci Code (Robert Langdon, #2)
# 12      4.36                                     The Book Thief
# 13      4.05  Alice's Adventures in Wonderland & Through the...
# ...

# %%
vals=ratingseries.values

# %%
df[['name','year']]
# Out:
#                                                    name  year
# 0               The Hunger Games (The Hunger Games, #1)  2008
# 1     Harry Potter and the Order of the Phoenix (Har...  2003
# 2                               Twilight (Twilight, #1)  2005
# 3                                 To Kill a Mockingbird  1960
# 4                                   Pride and Prejudice  1813
# 5                                    Gone with the Wind  1936
# 6     The Chronicles of Narnia (Chronicles of Narnia...  1949
# 7                                       The Giving Tree  1964
# 8                                           Animal Farm  1945
# 9     The Hitchhiker's Guide to the Galaxy (Hitchhik...  1979
# 10                                  Memoirs of a Geisha  1997
# 11               The Da Vinci Code (Robert Langdon, #2)  2003
# 12                                       The Book Thief  2005
# 13    Alice's Adventures in Wonderland & Through the...  1865
# ...

# %%
plt.hist(vals);

# %%
df[['name','year']].sort(['year'])
# Out:
#                                                    name  year
# 1398                              The Epic of Gilgamesh -1500
# 47                                          The Odyssey  -800
# 246                               The Iliad/The Odyssey  -800
# 1397                                     Aesop's Fables  -560
# 674                                      The Art of War  -512
# 746                                   The Bhagavad Gita  -500
# 1815                                       The Oresteia  -458
# 777                                            Antigone  -442
# 2527                                      The Histories  -440
# 1428                                              Medea  -431
# 629                                         Oedipus Rex  -429
# 2078               The History of the Peloponnesian War  -411
# 3757                                         Lysistrata  -411
# 1233                                  The Oedipus Cycle  -400
# ...

# %%
df.rating > 3.0
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# ...
# 5985    True
# 5986    True
# 5987    True
# 5988    True
# 5989    True
# 5990    True
# 5991    True
# 5992    True
# 5993    True
# 5994    True
# 5995    True
# 5996    True
# 5997    True
# 5998    True
# 5999    True
# Name: rating, Length: 6000, dtype: bool

# %%
df.rating[df.rating > 3.0]
# Out:
# 0     4.40
# 1     4.41
# 2     3.56
# 3     4.23
# 4     4.23
# 5     4.25
# 6     4.22
# 7     4.38
# 8     3.79
# 9     4.18
# 10    4.03
# 11    3.72
# 12    4.36
# 13    4.05
# 14    3.72
# ...
# 5985    3.61
# 5986    4.06
# 5987    4.26
# 5988    4.34
# 5989    3.36
# 5990    4.12
# 5991    4.20
# 5992    3.89
# 5993    4.09
# 5994    4.37
# 5995    4.17
# 5996    3.99
# 5997    3.78
# 5998    3.91
# 5999    4.35
# Name: rating, Length: 5994, dtype: float64

# %%
#Sorting by rating and name, with rating greater than 3
df[['rating','name']][df.rating > 3.0]
# Out:
#       rating                                               name
# 0       4.40            The Hunger Games (The Hunger Games, #1)
# 1       4.41  Harry Potter and the Order of the Phoenix (Har...
# 2       3.56                            Twilight (Twilight, #1)
# 3       4.23                              To Kill a Mockingbird
# 4       4.23                                Pride and Prejudice
# 5       4.25                                 Gone with the Wind
# 6       4.22  The Chronicles of Narnia (Chronicles of Narnia...
# 7       4.38                                    The Giving Tree
# 8       3.79                                        Animal Farm
# 9       4.18  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 10      4.03                                Memoirs of a Geisha
# 11      3.72             The Da Vinci Code (Robert Langdon, #2)
# 12      4.36                                     The Book Thief
# 13      4.05  Alice's Adventures in Wonderland & Through the...
# ...

# %%
#doing a thing, then a subset of that thing, and taking stuff out. make sure it's an AND and not an OR.
dfnew=df[['rating','name','rating_count']]
dfnew.head()
# Out:
#    rating                                               name rating_count
# 0    4.40            The Hunger Games (The Hunger Games, #1)      2958974
# 1    4.41  Harry Potter and the Order of the Phoenix (Har...      1284478
# 2    3.56                            Twilight (Twilight, #1)      2579564
# 3    4.23                              To Kill a Mockingbird      2078123
# 4    4.23                                Pride and Prejudice      1388992

# %%
dfnewnew=dfnew[dfnew.rating > 3.0]
dfnewnewnew=dfnewnew[dfnewnew.rating_count > 10000]
dfnewnewnew.sort(['rating'], ascending=[0])
# Out:
#       rating                                               name rating_count
# 1718    5.00                         An Elephant Is On My House           64
# 2145    5.00                   A Book About Absolutely Nothing.           63
# 5564    5.00               Untainted (Photographer Trilogy, #3)           14
# 2903    5.00              Obscured Darkness (Family Secrets #2)            8
# 2909    5.00                                     Family Secrets            9
# 4473    5.00                                    Patience's Love            7
# 5692    5.00  Abstraction In Theory - Laws Of Physical Trans...            6
# 2868    4.94                    Nik Nassa & the Mark of Destiny           16
# 2865    4.93                LaÃ§os fortes e decisÃµes difÃ­ceis           14
# 2920    4.93                                The Years Distilled           28
# 3712    4.93                                        Blade Heart           15
# ...

# %%
df.dtypes
# Out:
# rating          float64
# review_count     object
# isbn             object
# booktype         object
# author_url       object
# year            float64
# genre_urls       object
# dir              object
# rating_count     object
# name             object
# dtype: object

# %%
df.rating_count.isnull().sum()
# Out:
# 0

# %%
# all this stuff is muddled up. check the day 3 'more cute pandas' file for a finished/good example

# %%
dfnew[df.rating_count=='None']
# Out:
#       rating  name rating_count
# 3643     NaN  None         None
# 5282     NaN  None         None

# %%
dfnew=dfnew[df.rating_count!='None']

# %%
dfnew.rating_count=dfnew.rating_count.astype(np.int64)
dfnew.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-2bd035b7ff9b> in <module>()
# ----> 1 dfnew.rating_count=dfnew.rating_count.astype(np.int64)
#       2 dfnew.dtypes
#
# NameError: name 'np' is not defined

# %%
print type(vals)
vals
# Out:
# <type 'numpy.ndarray'>
# array([ 4.4 ,  4.41,  3.56, ...,  3.78,  3.91,  4.35])

# %% [markdown]
# But one dosent have to

# %%
df.rating.hist();

# %%
df.rating.hist();

# %%
sns.set_context("notebook")
meanrat=df.rating.mean()
print meanrat, np.mean(df.rating), df.rating.median()
with sns.axes_style("whitegrid"):
    df.rating.hist(bins=30, alpha=0.4);
    plt.axvline(meanrat, 0, 0.75, color='r', label='Mean')
    plt.xlabel("average rating of book")
    plt.ylabel("Counts")
    plt.title("Ratings Histogram")
    plt.legend()
    #sns.despine()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-2ccb42c55494> in <module>()
# ----> 1 sns.set_context("notebook")
#       2 meanrat=df.rating.mean()
#       3 print meanrat, np.mean(df.rating), df.rating.median()
#       4 with sns.axes_style("whitegrid"):
#       5     df.rating.hist(bins=30, alpha=0.4);
#
# NameError: name 'sns' is not defined

# %%
sns.set_context("notebook")
meanrat=df.rating.mean()
print meanrat, np.mean(df.rating), df.rating.median()
with sns.axes_style("whitegrid"):
    df.rating.hist(bins=30, alpha=0.4);
    plt.axvline(meanrat, 0, 0.75, color='r', label='Mean')
    plt.xlabel("average rating of book")
    plt.ylabel("Counts")
    plt.title("Ratings Histogram")
    plt.legend()
    #sns.despine()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-2ccb42c55494> in <module>()
# ----> 1 sns.set_context("notebook")
#       2 meanrat=df.rating.mean()
#       3 print meanrat, np.mean(df.rating), df.rating.median()
#       4 with sns.axes_style("whitegrid"):
#       5     df.rating.hist(bins=30, alpha=0.4);
#
# NameError: name 'sns' is not defined
